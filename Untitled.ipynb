# %%
import requests
HEADERS = {'User-Agent': 'python:nascar-sponsorship-analysis:v1.0 (by /u/Illustrious_Bat3466)'}
url = "https://www.reddit.com/r/NASCAR/search.json"
params = {'q': 'FedEx', 'restrict_sr': 1, 'sort': 'relevance', 't': 'year', 'limit': 100}
r = requests.get(url, headers=HEADERS, params=params)
print(r.status_code)  # want 200
# Out:
# 403
